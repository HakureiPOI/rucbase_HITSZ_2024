# %% [markdown]
# <a href="https://colab.research.google.com/github/HakureiPOI/rucbase_HITSZ_2024/blob/Lab1/rucbase_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HakureiPOI

# %% [markdown]
# ---
#
# ### 从 github 拉取已经配置好的实验环境

# %%
# !git clone -b Lab1 https://github.com/HakureiPOI/rucbase_HITSZ_2024.git
# Out:
# Cloning into 'rucbase_HITSZ_2024'...
# remote: Enumerating objects: 1153, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 1153 (delta 24), reused 85 (delta 24), pack-reused 1068 (from 1)
# Receiving objects: 100% (1153/1153), 43.84 MiB | 11.77 MiB/s, done.
# Resolving deltas: 100% (442/442), done.

# %%
# !unzip /content/rucbase_HITSZ_2024/rucbase-lab.zip >/dev/null 2>&1

# %%
# %cd /content/rucbase-lab/build
# Out:
# /content/rucbase-lab/build

# %%
# !nohup ./bin/rmdb test_db &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# !cat /content/rucbase-lab/build/nohup.out
# Out:
#   _____  __  __ _____  ____
#  |  __ \|  \/  |  __ \|  _ \
#  | |__) | \  / | |  | | |_) |
#  |  _  /| |\/| | |  | |  _ <
#  | | \ \| |  | | |__| | |_) |
#  |_|  \_\_|  |_|_____/|____/
#
# Welcome to RMDB!
# Type 'help;' for help.
#
# Waiting for new connection...

# %%
# %cd /content/rucbase-lab/rucbase_client/build
# Out:
# /content/rucbase-lab/rucbase_client/build

# %%
# ! ./rucbase_client

# %%
# %cd /content/rucbase-lab/build
# Out:
# /content/rucbase-lab/build

# %%
# !ls
# Out:
# bin			  CMakeFiles	       deps		   Makefile   test_db
# BufferPoolManagerTest_db  cmake_install.cmake  DiskManagerTest_db  nohup.out
# CMakeCache.txt		  CTestTestfile.cmake  lib		   src

# %%
# !apt-get update >/dev/null 2>&1
# !apt-get install -y bison >/dev/null 2>&1
# !apt-get install flex >/dev/null 2>&1

# %% [markdown]
# ---
# ### disk_managger.cpp

# %%
# !make disk_manager_test
# Out:
# [ 20%] Built target gtest
# [ 40%] Built target gtest_main
# [ 80%] Built target storage
# [ 90%] Linking CXX executable ../../bin/disk_manager_test
# [100%] Built target disk_manager_test

# %%
! ./bin/disk_manager_test
# Out:
# Running main() from /content/rucbase-lab/deps/googletest/googletest/src/gtest_main.cc
# [==========] Running 2 tests from 1 test suite.
# [----------] Global test environment set-up.
# [----------] 2 tests from DiskManagerTest
# [ RUN      ] DiskManagerTest.FileOperation
# [       OK ] DiskManagerTest.FileOperation (3 ms)
# [ RUN      ] DiskManagerTest.PageOperation
# [       OK ] DiskManagerTest.PageOperation (13 ms)
# [----------] 2 tests from DiskManagerTest (16 ms total)
#
# [----------] Global test environment tear-down
# [==========] 2 tests from 1 test suite ran. (17 ms total)
# [  PASSED  ] 2 tests.

# %% [markdown]
# ---
# ### lru_replacer

# %%
# !make lru_replacer_test
# Out:
# [ 25%] Built target gtest
# [ 50%] Built target gtest_main
# [ 75%] Built target lru_replacer
# [100%] Built target lru_replacer_test

# %%
! ./bin/lru_replacer_test
# Out:
# Running main() from /content/rucbase-lab/deps/googletest/googletest/src/gtest_main.cc
# [==========] Running 3 tests from 1 test suite.
# [----------] Global test environment set-up.
# [----------] 3 tests from LRUReplacerTest
# [ RUN      ] LRUReplacerTest.SimpleTest
# [       OK ] LRUReplacerTest.SimpleTest (0 ms)
# [ RUN      ] LRUReplacerTest.MixTest
# [       OK ] LRUReplacerTest.MixTest (19 ms)
# [ RUN      ] LRUReplacerTest.ConcurrencyTest
# [       OK ] LRUReplacerTest.ConcurrencyTest (145 ms)
# [----------] 3 tests from LRUReplacerTest (164 ms total)
#
# [----------] Global test environment tear-down
# [==========] 3 tests from 1 test suite ran. (165 ms total)
# [  PASSED  ] 3 tests.

# %% [markdown]
# ---
# ### buffer_pool_manager

# %%
# !make buffer_pool_manager_test
# Out:
# [ 20%] Built target gtest
# [ 40%] Built target gtest_main
# [ 80%] Built target storage
# [100%] Built target buffer_pool_manager_test

# %%
! ./bin/buffer_pool_manager_test
# Out:
# Running main() from /content/rucbase-lab/deps/googletest/googletest/src/gtest_main.cc
# [==========] Running 4 tests from 1 test suite.
# [----------] Global test environment set-up.
# [----------] 4 tests from BufferPoolManagerTest
# [ RUN      ] BufferPoolManagerTest.SimpleTest
# [       OK ] BufferPoolManagerTest.SimpleTest (74 ms)
# [ RUN      ] BufferPoolManagerTest.LargeScaleTest
# [       OK ] BufferPoolManagerTest.LargeScaleTest (240 ms)
# [ RUN      ] BufferPoolManagerTest.MultipleFilesTest
# [       OK ] BufferPoolManagerTest.MultipleFilesTest (1570 ms)
# [ RUN      ] BufferPoolManagerTest.ConcurrencyTest
# [       OK ] BufferPoolManagerTest.ConcurrencyTest (1757 ms)
# [----------] 4 tests from BufferPoolManagerTest (3642 ms total)
#
# [----------] Global test environment tear-down
# [==========] 4 tests from 1 test suite ran. (3642 ms total)
# [  PASSED  ] 4 tests.

# %% [markdown]
# ---
# ### record_manager

# %%
# !make record_manager_test
# Out:
# [  8%] Built target gtest
# [ 16%] Built target gtest_main
# [ 33%] Built target storage
# [ 45%] Built target index
# [ 58%] Built target recovery
# [ 70%] Built target transaction
# [ 79%] Built target system
# [ 91%] Built target record
# [100%] Built target record_manager_test

# %%
! ./bin/record_manager_test
# Out:
# Running main() from /content/rucbase-lab/deps/googletest/googletest/src/gtest_main.cc
# [==========] Running 2 tests from 1 test suite.
# [----------] Global test environment set-up.
# [----------] 2 tests from RecordManagerTest
# [ RUN      ] RecordManagerTest.SimpleTest
# insert 451
# delete 284
# update 265
# [       OK ] RecordManagerTest.SimpleTest (658 ms)
# [ RUN      ] RecordManagerTest.MultipleFilesTest
# [       OK ] RecordManagerTest.MultipleFilesTest (232 ms)
# [----------] 2 tests from RecordManagerTest (891 ms total)
#
# [----------] Global test environment tear-down
# [==========] 2 tests from 1 test suite ran. (891 ms total)
# [  PASSED  ] 2 tests.
